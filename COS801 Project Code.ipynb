# %% [markdown]
# ## Deep Learning on Tabular Data for Fraud Detection under Extreme Class Imbalance
#
# ### Group 2 Members
# 1. NB Ndlela (u22848322)
# 2. RY Muthadzwi (u26842328)
# 3.  u13353617
